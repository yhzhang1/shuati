# %%
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        visited = dict()
        
        for s in strs:
            s_ = ''.join(sorted(s))
            if s_ not in visited:
                visited[s_] = [s]
            else:
                visited[s_].append(s)
                
        return visited.values()
