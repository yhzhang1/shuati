# %% [markdown]
# https://leetcode.com/problems/word-ladder/solution/

# %%
import collections
class Solution:
    def __init__(self):
        self.length = 0
        self.all_combo_dict = defaultdict(list)
        
    def visitWordNode(self, queue, visited, othersVisited):
        currentWord, level = queue.popleft()
        for i in range(self.length):
            intermediateWord = currentWord[:i] + '*' + currentWord[i+1:]
            for word in self.all_combo_dict[intermediateWord]:
                if word in othersVisited:
                    return level + othersVisited[word]
                if word not in visited:
                    visited[word] = level + 1
                    queue.append((word, level + 1))
                    
        return None
        
    def ladderLength(self, beginWord: str, endWord: str, wordList: List[str]) -> int:
        if endWord not in wordList:
            return 0
        self.length = len(beginWord)
        for word in wordList:
            for i in range(self.length):
                self.all_combo_dict[word[:i] + '*' + word[i+1:]].append(word)
                
        queueBegin = collections.deque([(beginWord,1)])
        queueEnd = collections.deque([(endWord,1)])
        
        visitedBegin = {beginWord: 1}
        visitedEnd = {endWord: 1}
        
        ans = None
        
        while queueBegin and queueEnd:
            ans = self.visitWordNode(queueBegin, visitedBegin, visitedEnd)
            if ans:
                return ans
            ans = self.visitWordNode(queueEnd, visitedEnd, visitedBegin)
            if ans:
                return ans
            
        return 0

# %%
import collections
class Solution:
    def __init__(self):
        self.length = 0
        self.all_combo_dict = defaultdict(list)
        
    def visitWordNode(self, queue, visited, othersVisited):
        currentWord, level = queue.popleft()
        for i in range(self.length):
            intermediateWord = currentWord[:i] + '*' + currentWord[i+1:]
            for word in self.all_combo_dict[intermediateWord]:
                if word in othersVisited:
                    return level + othersVisited[word]
                if word not in visited:
                    visited[word] = level + 1
                    queue.append((word, level + 1))
                    
        return None
        
    def ladderLength(self, beginWord: str, endWord: str, wordList: List[str]) -> int:
        self.length = len(beginWord)
        for word in wordList:
            for i in range(L):
                self.all_combo_dict[word[:i] + '*' + word[i+1:]].append(word)
                
        queueBegin = collections.deque([(beginWord,1)])
        queueEnd = collections.deque([(endWord,1)])
        
        visitedBegin = {beginWord: 1}
        visitedEnd = {endWord: 1}
        
        ans = None
        
        while queueBegin and queueEnd:
            ans = self.visitWordNode(queueBegin, visitedBegin, visitedEnd)
            print('visitedBegin: ', visitedBegin)
            if ans:
                return ans
            ans = self.visitWordNode(queueEnd, visitedEnd, visitedBegin)
            print('visitedEnd: ', visitedEnd)
            if ans:
                return ans
            
        return 0

# %%
from collections import defaultdict
class Solution:
    def ladderLength(self, beginWord: str, endWord: str, wordList: List[str]) -> int:
        all_combo_dict = defaultdict(list)
        L = len(beginWord)
        for word in wordList:
            for i in range(L):
                intermediateWord = word[:i] + '*' + word[i+1:]
                all_combo_dict[intermediateWord].append(word)
                
        queue = collections.deque([(beginWord,1)])
        visited = {beginWord: True}
        while queue:
            currentWord, level = queue.popleft()
            for i in range(L):
                intermediateWord = currentWord[:i] + '*' + currentWord[i+1:]
                for word in all_combo_dict[intermediateWord]:
                    if word == endWord:
                        return level+1
                    if word not in visited:
                        visited[word] = True
                        queue.append((word, level+1))
                all_combo_dict[intermediateWord] = []
        return 0

# %%
from collections import defaultdict

help(defaultdict)
# Out:
# Help on class defaultdict in module collections:
#
# class defaultdict(builtins.dict)
#  |  defaultdict(default_factory[, ...]) --> dict with default factory
#  |
#  |  The default factory is called without arguments to produce
#  |  a new value when a key is not present, in __getitem__ only.
#  |  A defaultdict compares equal to a dict with the same items.
#  |  All remaining arguments are treated the same as if they were
#  |  passed to the dict constructor, including keyword arguments.
#  |
#  |  Method resolution order:
#  |      defaultdict
#  |      builtins.dict
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __copy__(...)
#  |      D.copy() -> a shallow copy of D.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __missing__(...)
# ...

# %%
d = {'a':1,'b':2,'c':3}
dd = defaultdict(d)
dd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-69a887b76d54> in <module>
#       1 d = {'a':1,'b':2,'c':3}
# ----> 2 dd = defaultdict(d)
#       3 dd
#
# TypeError: first argument must be callable or None

# %%
from collections import defaultdict

def def_value():
    return "Not Present"

d = defaultdict(def_value)
d['a'] = 1
d['b'] = 2

print(d['a'])
print(d['b'])
print(d['c'])
# Out:
# 1
# 2
# Not Present

# %%
from collections import defaultdict

beginWord = 'hit'
endWord = 'cog'
wordList = ["hot","dot","dog","lot","log","cog"]
L = len(beginWord)
all_combo_dict = defaultdict(list)

for word in wordList:
    for i in range(L):
        # Key is the generic word
        # Value is a list of words which have the same intermediate generic word.
        all_combo_dict[word[:i] + "*" + word[i+1:]].append(word)

queue = collections.deque([(beginWord, 1)])
visited = {beginWord: True}
while queue:
    current_word, level = queue.popleft()
    for i in range(L):
        intermediate_word = current_word[:i] + '*' + current_word[i+1:]
        
        for word in all_combo_dict[intermediate_word]:
            if word == endWord:
                return level + 1
            
            if word not in visited:
                visited[word] = True
                queue.append((word, level+1))

# %%
all_combo_dict
# Out:
# defaultdict(list,
#             {'*ot': ['hot', 'dot', 'lot'],
#              'h*t': ['hot'],
#              'ho*': ['hot'],
#              'd*t': ['dot'],
#              'do*': ['dot', 'dog'],
#              '*og': ['dog', 'log', 'cog'],
#              'd*g': ['dog'],
#              'l*t': ['lot'],
#              'lo*': ['lot', 'log'],
#              'l*g': ['log'],
#              'c*g': ['cog'],
#              'co*': ['cog']})

# %%
'a'+'*'+'c'
# Out:
# 'a*c'

# %%
all_combo_dict['*it']
# Out:
# []

# %%
from collections import defaultdict
import collections
class Solution(object):
    def ladderLength(self, beginWord, endWord, wordList):
        """
        :type beginWord: str
        :type endWord: str
        :type wordList: List[str]
        :rtype: int
        """

        if endWord not in wordList or not endWord or not beginWord or not wordList:
            return 0

        # Since all words are of same length.
        L = len(beginWord)

        # Dictionary to hold combination of words that can be formed,
        # from any given word. By changing one letter at a time.
        all_combo_dict = defaultdict(list)
        for word in wordList:
            for i in range(L):
                # Key is the generic word
                # Value is a list of words which have the same intermediate generic word.
                all_combo_dict[word[:i] + "*" + word[i+1:]].append(word)

        print('all_combo_dict: \n', all_combo_dict)

        # Queue for BFS
        queue = collections.deque([(beginWord, 1)])
        # Visited to make sure we don't repeat processing same word.
        visited = {beginWord: True}
        while queue:
            current_word, level = queue.popleft()      
            for i in range(L):
                # Intermediate words for current word
                intermediate_word = current_word[:i] + "*" + current_word[i+1:]
                print('intermediate_word: ', intermediate_word)
                # Next states are all the words which share the same intermediate state.
                for word in all_combo_dict[intermediate_word]:
                    # If at any point if we find what we are looking for
                    # i.e. the end word - we can return with the answer.
                    if word == endWord:
                        return level + 1
                    # Otherwise, add it to the BFS Queue. Also mark it visited
                    if word not in visited:
                        visited[word] = True
                        queue.append((word, level + 1))
                        print('queue: ', queue)
                all_combo_dict[intermediate_word] = []
                print('all_combo_dict: ', all_combo_dict)
        return 0

# %%
beginWord = 'hit'
endWord = 'cog'
wordList = ["hot","dot","dog","lot","log","cog"]
Solution().ladderLength(beginWord, endWord, wordList)
# Out:
# all_combo_dict:
#  defaultdict(<class 'list'>, {'*ot': ['hot', 'dot', 'lot'], 'h*t': ['hot'], 'ho*': ['hot'], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog']})
# intermediate_word:  *it
# all_combo_dict:  defaultdict(<class 'list'>, {'*ot': ['hot', 'dot', 'lot'], 'h*t': ['hot'], 'ho*': ['hot'], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': []})
# intermediate_word:  h*t
# queue:  deque([('hot', 2)])
# all_combo_dict:  defaultdict(<class 'list'>, {'*ot': ['hot', 'dot', 'lot'], 'h*t': [], 'ho*': ['hot'], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': []})
# intermediate_word:  hi*
# ...

# %%
from collections import defaultdict
import collections
from typing import List


beginWord = 'hit'
endWord = 'cog'
wordList = ["hot","dot","dog","lot","log","cog"]

def ladderLength(beginWord: str, endWord: str, wordList: List[str]) -> int:
    all_combo_dict = defaultdict(list)
    L = len(beginWord)
    for word in wordList:
        print('word: ', word)
        for i in range(L):
            intermediateWord = word[:i] + '*' + word[i+1:]
            print('intermediateWord: ', intermediateWord)
            all_combo_dict[intermediateWord].append(word)

    queue = collections.deque([(beginWord,1)])
    visited = {beginWord:True}
    while queue:
        currentWord, level = queue.popleft()
        print('currentWord {}, level {}'.format(currentWord, level))
        for i in range(L):
            intermediateWord = currentWord[:i] + '*' + currentWord[i+1:]
            for word in all_combo_dict[intermediateWord]:
                if word == endWord:
                    return level+1

                if word not in visited:
                    visited[word] = True
                    queue.append((word,level+1))
                    
    return 0

ladderLength(beginWord, endWord, wordList)
# Out:
# word:  hot
# intermediateWord:  *ot
# intermediateWord:  h*t
# intermediateWord:  ho*
# word:  dot
# intermediateWord:  *ot
# intermediateWord:  d*t
# intermediateWord:  do*
# word:  dog
# intermediateWord:  *og
# intermediateWord:  d*g
# intermediateWord:  do*
# word:  lot
# intermediateWord:  *ot
# intermediateWord:  l*t
# intermediateWord:  lo*
# word:  log
# intermediateWord:  *og
# intermediateWord:  l*g
# intermediateWord:  lo*
# word:  cog
# intermediateWord:  *og
# intermediateWord:  c*g
# intermediateWord:  co*
# currentWord hit, level 1
# currentWord hot, level 2
# currentWord dot, level 3
# currentWord lot, level 3
# currentWord dog, level 4
# 5

# %%
q = collections.deque([('a',1)])
q
# Out:
# deque([('a', 1)])

# %%
import collections
class Solution:
    def __init__(self):
        self.length = 0
        self.all_combo_dict = defaultdict(list)
        
    def visitWordNode(self, queue, visited, othersVisited):
        currentWord, level = queue.popleft()
        for i in range(self.length):
            intermediateWord = currentWord[:i] + '*' + currentWord[i+1:]
            for word in self.all_combo_dict[intermediateWord]:
                print(word)
                if word in othersVisited:
                    print(word)
                    return level + othersVisited[word]
                if word not in visited:
                    print('{} not in visited'.format(word))
                    visited[word] = level + 1
                    queue.append((word, level + 1))
                    
        return None
        
    def ladderLength(self, beginWord: str, endWord: str, wordList: List[str]) -> int:
        if endWord not in wordList:
            return 0
        self.length = len(beginWord)
        for word in wordList:
            for i in range(self.length):
                self.all_combo_dict[word[:i] + '*' + word[i+1:]].append(word)
                
        print('self.all_combo_dict: ', self.all_combo_dict)
                
        queueBegin = collections.deque([(beginWord,1)])
        queueEnd = collections.deque([(endWord,1)])
        
        visitedBegin = {beginWord: 1}
        visitedEnd = {endWord: 1}
        
        ans = None
        
        while queueBegin and queueEnd:
            print('visitWordNode')
            ans = self.visitWordNode(queueBegin, visitedBegin, visitedEnd)
            print('visitedBegin: ', visitedBegin)
            print('queueBegin: ', queueBegin)
            if ans:
                return ans
            ans = self.visitWordNode(queueEnd, visitedEnd, visitedBegin)
            print('visitedEnd: ', visitedEnd)
            print('queueEnd: ', queueEnd)
            if ans:
                return ans
            
        return 0

# %%
beginWord = "ymain"
endWord = "oecij"
wordList = ["ymann","yycrj","oecij","ymcnj","yzcrj","yycij","xecij","yecij","ymanj","yzcnj","ymain"]
Solution().ladderLength(beginWord, endWord, wordList)
# Out:
# self.all_combo_dict:  defaultdict(<class 'list'>, {'*mann': ['ymann'], 'y*ann': ['ymann'], 'ym*nn': ['ymann'], 'yma*n': ['ymann', 'ymain'], 'yman*': ['ymann', 'ymanj'], '*ycrj': ['yycrj'], 'y*crj': ['yycrj', 'yzcrj'], 'yy*rj': ['yycrj'], 'yyc*j': ['yycrj', 'yycij'], 'yycr*': ['yycrj'], '*ecij': ['oecij', 'xecij', 'yecij'], 'o*cij': ['oecij'], 'oe*ij': ['oecij'], 'oec*j': ['oecij'], 'oeci*': ['oecij'], '*mcnj': ['ymcnj'], 'y*cnj': ['ymcnj', 'yzcnj'], 'ym*nj': ['ymcnj', 'ymanj'], 'ymc*j': ['ymcnj'], 'ymcn*': ['ymcnj'], '*zcrj': ['yzcrj'], 'yz*rj': ['yzcrj'], 'yzc*j': ['yzcrj', 'yzcnj'], 'yzcr*': ['yzcrj'], '*ycij': ['yycij'], 'y*cij': ['yycij', 'yecij'], 'yy*ij': ['yycij'], 'yyci*': ['yycij'], 'x*cij': ['xecij'], 'xe*ij': ['xecij'], 'xec*j': ['xecij'], 'xeci*': ['xecij'], 'ye*ij': ['yecij'], 'yec*j': ['yecij'], 'yeci*': ['yecij'], '*manj': ['ymanj'], 'y*anj': ['ymanj'], 'yma*j': ['ymanj'], '*zcnj': ['yzcnj'], 'yz*nj': ['yzcnj'], 'yzcn*': ['yzcnj'], '*main': ['ymain'], 'y*ain': ['ymain'
# ...
